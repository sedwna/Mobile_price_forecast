# %%
import pandas as pd
df = pd.read_csv("../data/mobile.csv")
df = df.drop("index",axis=1)
df.head(10)
# Out:
#    battery_power blue  clock_speed sim type  fc four_g  int_memory  m_dep  \
# 0          842.0   no          2.2      one   1     no           7    0.6
# 1         1021.0  yes          0.5     dual   0    yes          53    0.7
# 2          563.0  yes          0.5     dual   2    yes          41    0.9
# 3          615.0  yes          2.5      one   0     no          10    0.8
# 4         1821.0  yes          1.2      one  13    yes          44    0.6
# 5         1859.0   no          0.5     dual   3     no          22    0.7
# 6         1821.0   no          1.7      one   4    yes          10    0.8
# 7         1954.0   no          0.5     dual   0     no          24    0.8
# 8         1445.0  yes          0.5      one   0     no          53    0.7
# 9          509.0  NaN          0.6     dual   2    yes           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0      188.0      2.0  ...       20.0     756.0  2549.0   9.0   7.0
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'sim type', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'type',
#        'wifi', 'price_range'],
#       dtype='object')

# %%
df["price_range"].value_counts()
# Out:
# price_range
# medium low     500
# medium high    500
# high           500
# low price      500
# Name: count, dtype: int64

# %%
df = df.replace({'yes':1,'no':0,'one': 1, 'dual': 2,'button':0,'touch screen':1,'no wifi':0,'has wifi':1,'medium low':0,'medium high':1,'high':2,'low price':3})

df
# Out:
# C:\Users\priso\AppData\Local\Temp\ipykernel_3284\2424393231.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({'yes':1,'no':0,'one': 1, 'dual': 2,'button':0,'touch screen':1,'no wifi':0,'has wifi':1,'medium low':0,'medium high':1,'high':2,'low price':3})
#       battery_power  blue  clock_speed  sim type  fc  four_g  int_memory  \
# 0             842.0   0.0          2.2       1.0   1     0.0           7
# 1            1021.0   1.0          0.5       2.0   0     1.0          53
# 2             563.0   1.0          0.5       2.0   2     1.0          41
# 3             615.0   1.0          2.5       1.0   0     0.0          10
# 4            1821.0   1.0          1.2       1.0  13     1.0          44
# ...

# %%
df = df.dropna()
df
# Out:
#       battery_power  blue  clock_speed  sim type  fc  four_g  int_memory  \
# 0             842.0   0.0          2.2       1.0   1     0.0           7
# 1            1021.0   1.0          0.5       2.0   0     1.0          53
# 2             563.0   1.0          0.5       2.0   2     1.0          41
# 3             615.0   1.0          2.5       1.0   0     0.0          10
# 4            1821.0   1.0          1.2       1.0  13     1.0          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995          794.0   1.0          0.5       2.0   0     1.0           2
# 1996         1965.0   1.0          2.6       2.0   0     0.0          39
# 1997         1911.0   0.0          0.9       2.0   1     1.0          36
# 1998         1512.0   0.0          0.9       1.0   4     1.0          46
# 1999          510.0   1.0          2.0       2.0   5     1.0          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       battery_power  blue  clock_speed  sim type  fc  four_g  int_memory  \
# 0             842.0   0.0          2.2       1.0   1     0.0           7
# 1            1021.0   1.0          0.5       2.0   0     1.0          53
# 2             563.0   1.0          0.5       2.0   2     1.0          41
# 3             615.0   1.0          2.5       1.0   0     0.0          10
# 4            1821.0   1.0          1.2       1.0  13     1.0          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995          794.0   1.0          0.5       2.0   0     1.0           2
# 1996         1965.0   1.0          2.6       2.0   0     0.0          39
# 1997         1911.0   0.0          0.9       2.0   1     1.0          36
# 1998         1512.0   0.0          0.9       1.0   4     1.0          46
# 1999          510.0   1.0          2.0       2.0   5     1.0          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# ...

# %%
X = df[['battery_power', 'blue', 'clock_speed', 'sim type', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'type',
       'wifi']]
X
# Out:
#       battery_power  blue  clock_speed  sim type  fc  four_g  int_memory  \
# 0             842.0   0.0          2.2       1.0   1     0.0           7
# 1            1021.0   1.0          0.5       2.0   0     1.0          53
# 2             563.0   1.0          0.5       2.0   2     1.0          41
# 3             615.0   1.0          2.5       1.0   0     0.0          10
# 4            1821.0   1.0          1.2       1.0  13     1.0          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995          794.0   1.0          0.5       2.0   0     1.0           2
# 1996         1965.0   1.0          2.6       2.0   0     0.0          39
# 1997         1911.0   0.0          0.9       2.0   1     1.0          36
# 1998         1512.0   0.0          0.9       1.0   4     1.0          46
# 1999          510.0   1.0          2.0       2.0   5     1.0          45
#
#       m_dep  mobile_wt  n_cores    pc  px_height  px_width     ram  sc_h  \
# ...

# %%
Y = df["price_range"].values
Y
# Out:
# array([0, 1, 1, ..., 2, 3, 2], dtype=int64)

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test = model_selection.train_test_split(X,Y,test_size=0.2,random_state=True)
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn import svm

clf = svm.SVC(kernel="rbf").fit(x_train,y_train)
yhat=clf.predict(x_test)
yhat
# Out:
# array([1, 1, 3, 2, 1, 2, 3, 3, 3, 1, 3, 0, 3, 0, 2, 1, 1, 2, 1, 1, 0, 2,
#        2, 1, 3, 0, 2, 0, 1, 2, 2, 2, 3, 3, 3, 3, 3, 3, 0, 1, 0, 2, 3, 0,
#        2, 0, 2, 1, 3, 1, 2, 1, 1, 0, 2, 3, 2, 3, 1, 3, 3, 3, 1, 3, 1, 1,
#        0, 0, 0, 0, 3, 0, 1, 1, 3, 0, 3, 0, 3, 1, 0, 1, 0, 2, 2, 3, 1, 3,
#        0, 1, 2, 1, 1, 3, 2, 1, 0, 3, 3, 0, 0, 1, 2, 3, 3, 2, 3, 3, 3, 2,
#        0, 1, 2, 0, 2, 0, 0, 0, 3, 1, 1, 2, 0, 1, 2, 2, 1, 1, 1, 3, 3, 2,
#        3, 3, 0, 2, 2, 2, 3, 1, 2, 2, 1, 3, 0, 0, 0, 2, 1, 0, 1, 0, 1, 3,
#        0, 3, 2, 0, 3, 2, 1, 2, 1, 0, 3, 1, 2, 3, 2, 0, 1, 2, 0, 1, 1, 2,
#        0, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2, 3, 1, 0, 0, 2, 1, 3, 0, 2, 2, 3,
#        3, 1, 2, 0, 0, 0, 0, 0, 3, 2, 3, 2, 2, 3, 2, 1, 2, 2, 1, 1, 1, 1,
#        3, 0, 2, 0, 0, 1, 0, 0, 0, 2, 2, 1, 2, 3, 1, 1, 3, 3, 3, 1, 3, 0,
#        3, 1, 0, 3, 0, 1, 1, 0, 1, 1, 3, 0, 2, 3, 3, 1, 0, 2, 1, 3, 0, 1,
#        0, 2, 2, 2, 2, 2, 0, 0, 2, 3, 0, 0, 3, 2, 1, 3, 0, 0, 1, 3, 3, 0,
# ...

# %%
from sklearn.metrics import accuracy_score ,confusion_matrix,f1_score
print(accuracy_score(y_train,clf.predict(x_train)))
print(accuracy_score(y_test,yhat))
print(f1_score(y_test,yhat, labels=None, pos_label=1, average="micro", sample_weight=None, zero_division='warn'))
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_test,yhat)
# Out:
# 0.9826923076923076
# 0.8593350383631714
# 0.8593350383631714
